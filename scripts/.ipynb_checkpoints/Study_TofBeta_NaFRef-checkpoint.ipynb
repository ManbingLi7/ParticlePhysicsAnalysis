# %%
import multiprocessing as mp                                                                                                                                                                                       
import os                                                                                                                                                                                                          
import numpy as np                                                                                                                                                                                                 
import awkward as ak                                                                                                                                                                                               
import matplotlib.pyplot as plt                                                                                                                                                                                    
import matplotlib                                                                                                                                                                                                  
import matplotlib.colors as colors                                                                                                                                                                                 
from tools.roottree import read_tree                                                                                                                                                                               
from tools.selections import *                                                                                                                                                                                     
import scipy.stats                                                                                                                                                                                                 
from scipy.optimize import curve_fit                                                                                                                                                                               
                                                                                                                   
from tools.plottools import plot1dhist, plot2dhist, plot1d_errorbar, FIGSIZE_MID, FIGSIZE_BIG, setplot_defaultstyle, format_order_of_magnitude, FONTSIZE                                                           
from tools.studybeta import calc_signal_fraction                                                                                
from tools.binnings_collection import fbinning_fraction, fbinning_RICHnpe                                                                                                                                          
from tools.binnings_collection import get_nbins_in_range, get_sub_binning, get_bin_center                                                                                                                          
from tools.studybeta import minuitfit_LL, cdf_gaussian, calc_signal_fraction, cdf_double_gaus, double_gaus, minuitfit_Chi
from tools.histograms import WeightedHistogram, Histogram, plot_histogram_2d, plot_histogram_1d   
from tools.plottools import plot1dhist, plot2dhist, plot1d_errorbar, savefig_tofile, setplot_defaultstyle, FIGSIZE_BIG, FIGSIZE_SQUARE, FIGSIZE_MID, FIGSIZE_WID, plot1d_step, FONTSIZE, set_plot_defaultstyle  
from tools.constants import ISOTOPES_MASS, NUCLEI_CHARGE, NUCLEIS, ISOTOPES
from tools.functions import cumulative_norm_gaus, normalized_gaussian
from tools.graphs import MGraph, slice_graph, plot_graph, slice_graph_by_value, concatenate_graphs

# %%
#filename_hist = '/home/manbing/Documents/Data/data_BeP7_Iso/BeMC_betaHighR_rwthB1220raw3.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/O_betaHighR_B1236P8_beta2.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/O_betaHighR_B1236P8_richbeta1.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/C_betaHighR_B1236P8_richbeta1.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/Be_betaHighR_B1236P8_richbeta1.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/C_tofbeta_refNaFtuned_B1236P8_mcweight.npz'
#filename_hist = '/home/manbing/Documents/Data/data_BeP8/C_tofbeta2_refNaFbeta1_B1236P8_mcweight.npz'
filename_hist = '/home/manbing/Documents/Data/data_BeP8/O_tofbeta2_refNaFbeta2tuned_B1236P8_mcweight.npz'

df = np.load(f'{filename_hist}')
detectors = ['Tof', 'NaF', 'Agl']
hist_mcbeta = {}
hist_issbeta = {}
hist_issbeta_sv = {}
nuclei = 'O'
isotopes = ISOTOPES[nuclei]
nucleiname = 'Oxygen'
MCName = 'O16'
plotfile = '/home/manbing/Documents/lithiumanalysis/slides/isotopes_1010/plots_1010'
isscolor = 'black'
mccolor = 'blue'

# %%
file_tofbeta = '/home/manbing/Documents/Data/data_BeP7_Iso/BeMC_tofbeta_refNaF_B1236test.npz'
datatype = {'iss', 'mc'}

with np.load(filename_hist) as npzfile:
    hist2d_iss = WeightedHistogram.from_file(npzfile, f"hist_issbetareso_NaF") 
    hist2d_mc = WeightedHistogram.from_file(npzfile, f"hist_mcbetareso_mix_NaF")  
    
    fig = plt.figure(figsize=(20, 15))
    plot = fig.subplots(1, 1) 
    plot2dhist(fig, plot, xbinning=hist2d_iss.binnings[0].edges[1:-1], 
               ybinning=hist2d_iss.binnings[1].edges[1:-1], 
               counts=hist2d_iss.values[1:-1, 1:-1], 
               xlabel=None, ylabel=None, zlabel="counts", zmin=None, zmax=None, 
               setlogx=False, setlogy=False, setscilabelx=False, setscilabely=False,  setlogz=False)  
    plot.text(0.05, 0.98, f"{nucleiname} ISS", fontsize=FONTSIZE, verticalalignment='top', horizontalalignment='left', transform=plot.transAxes, color="black", fontweight="bold")          
    plot.set_xlabel(r"Ekin/n(GeV/n)", fontsize=30)                                                                                                                                                     
    plot.set_ylabel(r'$\mathrm{\beta_{tof} - \beta_{naf}}$', fontsize=30)
    plot.set_xscale('log')
    #plot.set_xlim(gammalim[dec])
    savefig_tofile(fig, plotfile, f"hist2d_{figsuffix}_Compare_iss_{nucleiname}", show=True)

# %%
fig = plt.figure(figsize=(20, 15))
plot = fig.subplots(1, 1) 
plot2dhist(fig, plot, xbinning=hist2d_mc.binnings[0].edges[1:-1], 
            ybinning=hist2d_mc.binnings[1].edges[1:-1], 
            counts=hist2d_mc.values[1:-1, 1:-1], 
            xlabel=None, ylabel=None, zlabel="counts", zmin=None, zmax=None, 
            setlogx=False, setlogy=False, setscilabelx=False, setscilabely=False,  setlogz=False)  
plot.text(0.05, 0.98, f"{nucleiname} MC", fontsize=FONTSIZE, verticalalignment='top', horizontalalignment='left', transform=plot.transAxes, color="black", fontweight="bold")          
plot.set_xlabel(r"Ekin/n(GeV/n)", fontsize=30)                                                                                                                                                     
plot.set_ylabel(r'$\mathrm{\beta_{tof} - \beta_{naf}}$', fontsize=30)
plot.set_xscale('log')
#plot.set_xlim(gammalim[dec])
savefig_tofile(fig, plotfile, f"hist2d_{figsuffix}_Compare_mc_{nucleiname}", show=True)

# %%
minbin = 6
maxbin = 27
energy_binvalues = hist2d_iss.binnings[0].bin_centers[minbin:maxbin]
graph_mean_iss = MGraph(energy_binvalues, np.zeros_like(energy_binvalues), yerrs=np.zeros_like(energy_binvalues))
graph_sigma_iss = MGraph(energy_binvalues, np.zeros_like(energy_binvalues), yerrs=np.zeros_like(energy_binvalues))
graph_mean_mc = MGraph(energy_binvalues, np.zeros_like(energy_binvalues), yerrs=np.zeros_like(energy_binvalues))
graph_sigma_mc = MGraph(energy_binvalues, np.zeros_like(energy_binvalues), yerrs=np.zeros_like(energy_binvalues))


for ip, ibin in enumerate(range(minbin, maxbin)):
    hist1d_iss =  hist2d_iss.project(ibin) 
    lowbinedge = hist2d_iss.binnings[0].edges[ibin]
    upbinedge = hist2d_iss.binnings[0].edges[ibin + 1]
    hist1d_iss = hist1d_iss * (1/np.sum(hist1d_iss.values))
    hist1d_mc = hist2d_mc.project(ibin) 
    hist1d_mc = hist1d_mc * (1/np.sum(hist1d_mc.values))
    
    xrange = [-0.01, 0.018]
    xbinrange = hist1d_iss.binnings[0].get_indices(xrange)
    xedges_iss = hist1d_iss.binnings[0].edges[xbinrange[0]:xbinrange[1]+1]
    xvalue_iss = hist1d_iss.binnings[0].bin_centers[xbinrange[0]:xbinrange[1]]
    yvalue_iss = hist1d_iss.values[xbinrange[0]:xbinrange[1]]
    yvalueserr_iss = np.sqrt(hist1d_iss.squared_values[xbinrange[0]:xbinrange[1]])
    
    xedges_mc = hist1d_mc.binnings[0].edges[xbinrange[0]:xbinrange[1]+1]
    xvalue_mc = hist1d_mc.binnings[0].bin_centers[xbinrange[0]:xbinrange[1]]
    yvalue_mc = hist1d_mc.values[xbinrange[0]:xbinrange[1]]
    yvalueserr_mc = np.sqrt(hist1d_mc.squared_values[xbinrange[0]:xbinrange[1]])
    yvalueserr_mc[yvalueserr_mc==0] = 0.0001
    guess_gaus_iss = dict(norm=0.0005, mu=0.003, sigma=0.007)
    guess_gaus_mc = dict(norm=0.0005, mu=0.003, sigma=0.01)
    #par_iss, parerr_iss = minuitfit_LL(yvalue_iss, xedges_iss , cumulative_norm_gaus, guess_gaus_iss)                                                                                                                  
    #par_mc, parerr_mc = minuitfit_LL(yvalue_mc, xedges_mc, cumulative_norm_gaus, guess_gaus_mc)  
    par_iss, parerr_iss = minuitfit_Chi(xvalue_iss, yvalue_iss, yvalueserr_iss, normalized_gaussian , guess_gaus_iss)
    par_mc, parerr_mc = minuitfit_Chi(xvalue_mc, yvalue_mc, yvalueserr_mc,normalized_gaussian, guess_gaus_mc)
    for key in guess_gaus_iss.keys():
        guess_gaus_iss[key] = par_iss[key]
        guess_gaus_mc[key] = par_mc[key]
    
    xrange_iter2 = [guess_gaus_iss['mu'] - 2.8 * guess_gaus_iss['sigma'], guess_gaus_iss['mu'] + 2.8 * guess_gaus_iss['sigma']]
    xbinrange2 = hist1d_iss.binnings[0].get_indices(xrange_iter2)
    xrange_iter2mc = [guess_gaus_mc['mu'] - 2.8 * guess_gaus_mc['sigma'], guess_gaus_mc['mu'] + 2.8 * guess_gaus_mc['sigma']]
    xbinrange2mc = hist1d_iss.binnings[0].get_indices(xrange_iter2mc)
    
    xedges_iss = hist1d_iss.binnings[0].edges[xbinrange2[0]:xbinrange2[1]+1]
    xvalue_iss = hist1d_iss.binnings[0].bin_centers[xbinrange2[0]:xbinrange2[1]]
    yvalue_iss = hist1d_iss.values[xbinrange2[0]:xbinrange2[1]]
    yvalueserr_iss = np.sqrt(hist1d_iss.squared_values[xbinrange2[0]:xbinrange2[1]])
    
    xedges_mc = hist1d_mc.binnings[0].edges[xbinrange2mc[0]:xbinrange2mc[1]+1]
    xvalue_mc = hist1d_mc.binnings[0].bin_centers[xbinrange2mc[0]:xbinrange2mc[1]]
    yvalue_mc = hist1d_mc.values[xbinrange2mc[0]:xbinrange2mc[1]]
    yvalueserr_mc = np.sqrt(hist1d_mc.squared_values[xbinrange2mc[0]:xbinrange2mc[1]])
    yvalueserr_mc[yvalueserr_mc==0] = 0.0001
    
    par_iss, parerr_iss = minuitfit_Chi(xvalue_iss, yvalue_iss, yvalueserr_iss, normalized_gaussian , guess_gaus_iss)
    par_mc, parerr_mc = minuitfit_Chi(xvalue_mc, yvalue_mc, yvalueserr_mc,normalized_gaussian, guess_gaus_mc)
    #par_iss, parerr_iss = minuitfit_LL(yvalue_iss, xedges_iss , cumulative_norm_gaus, guess_gaus_iss)  
    #par_mc, parerr_mc = minuitfit_LL(yvalue_mc, xedges_mc , cumulative_norm_gaus, guess_gaus_mc)  
    #print("iss iter2:", par_iss) 
    #print("mc iter2:", par_mc) 
    graph_mean_iss.yvalues[ip] = par_iss['mu']
    graph_mean_iss.yerrs[ip] = parerr_iss['mu']
    graph_sigma_iss.yvalues[ip] = par_iss['sigma']
    graph_sigma_iss.yerrs[ip] = parerr_iss['sigma']
    graph_mean_mc.yvalues[ip] = par_mc['mu']
    graph_mean_mc.yerrs[ip] = parerr_mc['mu']
    graph_sigma_mc.yvalues[ip] = par_mc['sigma']
    graph_sigma_mc.yerrs[ip] = parerr_mc['sigma']
    
    fit_y_iss = normalized_gaussian(xvalue_iss, *par_iss)                                                                                                                                                              
    fit_y_mc = normalized_gaussian(xvalue_mc, *par_mc) 
    
    
    figure, ax1 = plt.subplots(1, 1, figsize=(17, 14))
    plot_histogram_1d(ax1, hist1d_iss, style="iss", color=isscolor, label=None, scale=None, gamma=None, xlog=False, ylog=False, shade_errors=False, setscilabely=True, show_overflow=False) 
    plot_histogram_1d(ax1, hist1d_mc, style="mc", color=mccolor, label=None, scale=None, gamma=None, xlog=False, ylog=False, shade_errors=False, setscilabely=True, show_overflow=False) 
    #ax1.legend()
    ax1.plot(xvalue_iss, fit_y_iss, '-', linewidth=3, color='black')
    ax1.plot(xvalue_mc, fit_y_mc, '-', linewidth=3, color='blue')
    ax1.text(0.6, 0.98, f"[{lowbinedge:.2f}, {upbinedge:.2f}] GeV/n", fontsize=FONTSIZE, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color="black", fontweight="bold") 
    ax1.text(0.03, 0.98, f'{nuclei} Data', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=isscolor, weight='normal')  
    ax1.text(0.03, 0.93, f"$\\mu:$ {par_iss['mu']:.4f}$\\pm$ {parerr_iss['mu']:.4f}", fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=isscolor, weight='normal')  
    ax1.text(0.03, 0.88, f"$\\sigma:$ {par_iss['sigma']:.4f}$\\pm$ {parerr_iss['sigma']:.4f}", fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=isscolor, weight='normal')  
    ax1.set_ylim([0.0001, 0.1])
    
    ax1.text(0.03, 0.8, f'{MCName} MC', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=mccolor, weight='normal')  
    ax1.text(0.03, 0.75, f"$\\mu:$ {par_mc['mu']:.4f}$\\pm$ {parerr_mc['mu']:.4f}", fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=mccolor, weight='normal')  
    ax1.text(0.03, 0.7, f"$\\sigma:$ {par_mc['sigma']:.4f}$\\pm$ {parerr_mc['sigma']:.4f}", fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=mccolor, weight='normal')  
    ax1.set_ylabel('Normalized events')
    ax1.set_xlabel(r'$\mathrm{\beta_{tof}-\beta_{naf}}$')
    ax1.set_xlim([-0.07, 0.06])
    ax1.set_yscale('log')
    savefig_tofile(figure, plotfile, f"hist1d_{figsuffix}_Compare_{ibin}_{nuclei}", show=True) 
    
print(graph_mean_iss)
print(graph_mean_mc)
# Out:
# /tmp/ipykernel_7160/3841849198.py:75: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figure, ax1 = plt.subplots(1, 1, figsize=(17, 14))
# xvalues			yvalues			yerrs
# 0.9302999999999999			0.00927802715595922			1.9594235770858263e-05
# 1.08555			0.007136103435697556			2.0640915890161986e-05
# 1.2570999999999999			0.005585535139920922			2.1722696583846445e-05
# 1.44745			0.004389881832124872			2.2426671277697015e-05
# 1.6566			0.0035625728511636486			2.339505670173829e-05
# 1.8872			0.0028786551696000024			2.4161388729726432e-05
# 2.1419			0.0023439581635802892			2.487397426272633e-05
# 2.42075			0.0018772630106850081			2.5933433403663168e-05
# 2.7237			0.0014652570759204802			2.6878711061769082e-05
# 3.0534			0.0011775446806243813			2.8261542644746896e-05
# 3.4126000000000003			0.0008786618658147474			2.9467197085149484e-05
# 3.8012500000000005			0.00043935055684525965			3.1120466851923934e-05
# 4.2221			0.00022676045667757117			3.21034823587511e-05
# 4.67795			-7.989435540439472e-05			3.325743894013805e-05
# 5.16875			-0.00026823607683040205			3.442571313375333e-05
# 5.70575			-0.0005737564152918538			3.523222245163855e-05
# 6.27195			-0.0007296830492657667			3.825595734502678e-05
# 6.8673			-0.0010527155789715997			4.0364503415592315e-05
# 7.5200499999999995			-0.0010549513726111769			4.2752252657049586e-05
# 8.2303			-0.0011950646414711442			4.581671992123824e-05
# 8.99805			-0.0013263033739007069			5.039018990414899e-05
#
#
# xvalues			yvalues			yerrs
# 0.9302999999999999			0.008303027448044592			0.0
# 1.08555			0.006575675621261943			7.035062888843643e-05
# 1.2570999999999999			0.005120856708667855			7.105814154810193e-05
# 1.44745			0.004033585480629581			7.33260389003569e-05
# 1.6566			0.003090245388641573			7.621387103911873e-05
# 1.8872			0.0024724436587475643			7.32075035446024e-05
# 2.1419			0.0018541172968692878			7.497736066144708e-05
# 2.42075			0.0013721499196144467			7.492988658139329e-05
# 2.7237			0.0010825188760845191			7.524310400154625e-05
# 3.0534			0.0009601436792661525			7.714158889430177e-05
# 3.4126000000000003			0.0004652120792024219			7.587671819327563e-05
# 3.8012500000000005			0.00041175306275694504			7.653295189068538e-05
# 4.2221			0.00026685815050656167			7.680893441332012e-05
# 4.67795			0.0002172171744557565			7.532001456987778e-05
# 5.16875			1.6170946254444598e-05			7.730242616242605e-05
# 5.70575			0.00010904787196273077			7.576544167708681e-05
# 6.27195			-9.182424896800284e-05			7.879771319191188e-05
# 6.8673			-7.627601350383912e-05			7.885906326681023e-05
# 7.5200499999999995			2.6975028027783147e-06			7.83527230333596e-05
# 8.2303			-0.0001246215922165792			8.109274382143849e-05
# 8.99805			-0.0003086660667601417			8.05138991158783e-05

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(21, 16))

plot_graph(fig, ax1, graph_mean_iss, color=isscolor,  style="EP", xlog=True, ylog=False, scale=None, markersize=22, label=f'{nuclei} Data') 
plot_graph(fig, ax1, graph_mean_mc, color=mccolor,  style="EP", xlog=True, ylog=False, scale=None, markersize=22, label=f'{MCName} MC')  
ax1.set_xlabel('Ekin/n (GeV/n)')
ax1.set_ylabel(r'$\mathrm{\mu_{(\beta_{Tof} - \beta_{NaF})}}$')
ax1.text(0.7, 0.98, f'{nuclei} Data', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=isscolor, weight='normal')  
ax1.text(0.7, 0.94, f'{MCName} MC', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=mccolor, weight='normal')
ax1.set_ylim([-0.005, 0.01])
savefig_tofile(fig, plotfile, f"graph_mean_{figsuffix}_{nuclei}", show=True)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(21, 16))

plot_graph(fig, ax1, graph_sigma_iss, color=isscolor,  style="EP", xlog=True, ylog=False, scale=None, markersize=22, label=f'{nuclei} Data') 
plot_graph(fig, ax1, graph_sigma_mc, color=mccolor,  style="EP", xlog=True, ylog=False, scale=None, markersize=22, label=f'{MCName} MC')  
ax1.set_xlabel('Ekin/n (GeV/n)')
ax1.set_ylabel(r'$\mathrm{\sigma_{(\beta_{Tof} - \beta_{NaF})}}$')
ax1.text(0.7, 0.98, f'{nuclei} Data', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=isscolor, weight='normal')  
ax1.text(0.7, 0.94, f'{MCName} MC', fontsize=30, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color=mccolor, weight='normal')  
ax1.set_ylim([0.003, 0.012])
savefig_tofile(fig, plotfile, f"graph_sigma_{figsuffix}_{nuclei}", show=True)

# %%
decs = ['NaF', 'Agl']
df_beta1 = np.load('/home/manbing/Documents/Data/data_BeP8/Be7MC_beta.npz')
df_beta2 = np.load('/home/manbing/Documents/Data/data_BeP8/Be7MC_betacor.npz')

hist_beta1 = {}
hist_beta2 = {}
for dec in decs:
    hist_beta1[dec] =  WeightedHistogram.from_file(df_beta1, f'hist_beta_{dec}_Be7')
    hist_beta2[dec] =  WeightedHistogram.from_file(df_beta2, f'hist_beta_{dec}_Be7')
    
    fig, ax1 = plt.subplots(1, 1, figsize=(21, 16))
    plot_histogram_1d(ax1, hist_beta1[dec], style='mc', label=r"$\beta$", color=mccolor,  scale=None, gamma=None, xlog=False, ylog=True, shade_errors=False, show_overflow=False, adjust_limits=None, adjust_limits_x=None, adjust_limits_y=None, flip_axes=False, override_limits=False, use_approximate_poisson_errors=False, draw_zeros=True, adjust_figure=True, markersize=20)
    plot_histogram_1d(ax1, hist_beta2[dec], style='mc', label=r"$\mathrm{\beta_{cor}}$", color=isscolor,scale=None, gamma=None, xlog=False, ylog=True, shade_errors=False, show_overflow=False, adjust_limits=None, adjust_limits_x=None, adjust_limits_y=None, flip_axes=False, override_limits=False, use_approximate_poisson_errors=False, draw_zeros=True, adjust_figure=True, markersize=20)
    ax1.text(0.5, 0.98, f"Be7 MC {dec} (P8)", fontsize=FONTSIZE, verticalalignment='top', horizontalalignment='left', transform=ax1.transAxes, color="black", fontweight="bold") 
    #ax1.set_ylim([0.01, 100000]) 
    ax1.legend()
    ####normalize it to 1
    savefig_tofile(fig, plotfile, f"{dec}_beta", show=True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7160/2278251426.py in <module>
#       6 hist_beta2 = {}
#       7 for dec in decs:
# ----> 8     hist_beta1[dec] =  WeightedHistogram.from_file(df_beta1, f'hist_beta_{dec}_Be7')
#       9     hist_beta2[dec] =  WeightedHistogram.from_file(df_beta2, f'hist_beta_{dec}_Be7')
#      10
#
# ~/Documents/lithiumanalysis/scripts/tools/histograms.py in from_file(file_dict, name)
#     254     @staticmethod
#     255     def from_file(file_dict, name):
# --> 256         binning_log = [bool(file_dict[f"{name}_binning_{index}_log"]) for index in range(file_dict[f"{name}_dimensions"])]
#     257         binnings = [Binning.from_file(file_dict, f"{name}_binning_{index}") for index in range(file_dict[f"{name}_dimensions"])]
#     258         dimensions = len(binnings)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     249                 return self.zip.read(key)
#     250         else:
# --> 251             raise KeyError("%s is not a file in the archive" % key)
#     252
#     253
#
# KeyError: 'hist_beta_Agl_Be7_dimensions is not a file in the archive'
